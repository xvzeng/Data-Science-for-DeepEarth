# %% [markdown]
# <a href="https://colab.research.google.com/github/xvzeng/Data-Science-for-Geochemistry/blob/main/Diamonds_XGboost_CV_AllKnown_Top5Craton_Imbalance_Predict_Unknown_Note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diamonds_XGBoost_CV_AllKnown_Top5Craton_Imbalance_Predict_Unknown_Note
#
# By Vivian Zeng
#
# JAN/30/2021

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings('ignore')

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, r2_score, make_scorer, f1_score, recall_score, precision_score
from sklearn.model_selection import GridSearchCV

import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import matplotlib as mpl
import lightgbm as lgb
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import LabelBinarizer, LabelEncoder

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d35f1e4e-ec32-4b9b-b264-4b57107652eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d35f1e4e-ec32-4b9b-b264-4b57107652eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Diamind_XZ_20201215_AllKnown.csv to Diamind_XZ_20201215_AllKnown (1).csv

# %%
import io
diamond = pd.read_csv(io.BytesIO(uploaded['Diamind_XZ_20201215_AllKnown.csv']))

# %%
diamond.columns
# Out:
# Index(['Unnamed: 0', 'craton', 'Si', 'Ti', 'Al', 'Cr', 'V', 'Mn', 'Mg', 'Ca',
#        'Sr', 'Ba', 'Na', 'P', 'K', 'Fe', 'Co', 'Ni', 'S', 'Zn', 'Cr_trace',
#        'Co_trace', 'Ni_trace', 'Sr_trace', 'Y_trace', 'Zr_trace', 'Nb_trace',
#        'Ba_trace', 'La_trace', 'Ce_trace', 'Nd_trace', 'Sm_trace', 'Eu_trace',
#        'Dy_trace', 'Er_trace', 'Yb_trace', 'Ti_trace', 'Fe_trace', 'Al_trace',
#        'Ca_trace', 'Mn_trace', 'Mg_trace', 'NAs'],
#       dtype='object')

# %%
df = diamond.copy()

# %%
df.drop(df.columns[df.isna().mean() == 1], axis=1, inplace=True)  # Remove columns that 100% missing 
df.shape
# Out:
# (2144, 43)

# %%
df.groupby('craton').describe()
# Out:
#                      Unnamed: 0                                            \
#                           count         mean         std     min      25%
# craton
# Alluvial                   38.0   761.500000   11.113055   743.0   752.25
# Amazonia                  207.0  1055.270531  677.813979     1.0   513.50
# Buffalo Head Terrane        6.0  1434.833333  416.548397  1052.0  1114.25
# Congo                     101.0   899.524752  404.102601   100.0   829.00
# East European              10.0  1524.000000  514.399326  1034.0  1036.25
# Gawler                     17.0  1234.294118  274.371273  1114.0  1118.00
# Guyana                     57.0  1237.070175  432.683894   790.0   984.00
# Kaapvaal                  410.0   517.324390  388.768068    89.0   199.25
# Kalahari                    4.0   980.500000    1.290994   979.0   979.75
# Pohorje                    10.0  1881.900000  406.249089  1084.0  2071.25
# Siberia                   695.0  1468.441727  460.221121    39.0  1435.50
# Slave                     330.0  1335.057576  535.337765    62.0  1048.25
# Superior                   86.0   588.930233  468.682227    79.0   365.25
# Tarim                      12.0  1202.500000    3.605551  1197.0  1199.75
# West Africa                98.0   309.020408   48.662520   257.0   281.25
# Wyoming                    35.0   496.800000   85.166895   466.0   474.50
# Zimbabwe                   28.0  1326.250000  411.258018  1009.0  1015.75
#
#                                                   Si                        \
#                          50%      75%     max  count       mean        std
# craton
# Alluvial               761.5   770.75   780.0   38.0  20.339523   4.471555
# Amazonia              1290.0  1389.50  2070.0  205.0   9.923860  10.606124
# West Africa            0.000000   0.025829   0.328416   98.0  0.000000e+00
# Wyoming                0.047894   7.751986  45.540352   34.0  0.000000e+00
# Zimbabwe              29.577966  43.455253  45.410354   28.0  2.111930e-02
#
#                                                                            \
#                                std  min           25%       50%       75%
# craton
# Alluvial                       NaN  NaN           NaN       NaN       NaN
# Amazonia              6.328785e-02  0.0  0.000000e+00  0.000000  0.120647
# Buffalo Head Terrane  0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Congo                 1.794518e-02  0.0  6.797000e-07  0.020391  0.033985
# East European         0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Gawler                0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Guyana                0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Kaapvaal              1.980877e-02  0.0  0.000000e+00  0.000000  0.000000
# Kalahari                       NaN  NaN           NaN       NaN       NaN
# Pohorje               0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Siberia               0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Slave                 5.839043e-08  0.0  0.000000e+00  0.000000  0.000000
# Superior              1.028198e-02  0.0  0.000000e+00  0.000000  0.000000
# Tarim                 0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# West Africa           0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Wyoming               0.000000e+00  0.0  0.000000e+00  0.000000  0.000000
# Zimbabwe              4.007685e-02  0.0  0.000000e+00  0.000000  0.010196
#
#                                        Mn                                \
#                                max  count      mean       std       min
# craton
# Alluvial                       NaN   38.0  0.142041  0.076244  0.046464
# Amazonia              1.767220e-01  205.0  0.269376  0.751027  0.000000
# Buffalo Head Terrane  0.000000e+00    6.0  0.167787  0.161749  0.046464
# Congo                 6.117300e-02   17.0  0.074251  0.083183  0.000000
# East European         0.000000e+00   10.0  0.147136  0.128808  0.000000
# Gawler                0.000000e+00   17.0  1.086438  3.911036  0.085184
# Guyana                0.000000e+00   55.0  0.183181  0.119452  0.000000
# Kaapvaal              2.175040e-01  409.0  0.175822  0.215815  0.000000
# Kalahari                       NaN    1.0  0.309760       NaN  0.309760
# Pohorje               0.000000e+00   10.0  0.000000  0.000000  0.000000
# Siberia               0.000000e+00  636.0  0.105116  0.120020  0.000000
# Slave                 6.797000e-07  308.0  0.189874  1.368851  0.000000
# Superior              4.078200e-02   86.0  0.142724  0.122354  0.000000
# Tarim                 0.000000e+00   12.0  0.000000  0.000000  0.000000
# West Africa           0.000000e+00   98.0  0.049198  0.131855  0.000000
# Wyoming               0.000000e+00   35.0  0.130099  0.081107  0.046464
# Zimbabwe              1.359400e-01   28.0  0.042039  0.072719  0.000000
#
#                                                                           Mg  \
#                                25%           50%       75%        max  count
# craton
# Alluvial              6.969600e-02  1.471360e-01  0.193600   0.286528   38.0
# Amazonia              8.518400e-02  1.703680e-01  0.224576   8.874624  205.0
# Buffalo Head Terrane  5.420800e-02  8.131200e-02  0.300080   0.379456    6.0
# Congo                 3.097600e-02  5.420800e-02  0.085184   0.332992   17.0
# East European         1.936000e-02  1.548800e-01  0.232320   0.309760   10.0
# Gawler                1.161600e-01  1.316480e-01  0.147136  16.262400   17.0
# Guyana                7.744000e-02  1.858560e-01  0.243936   0.596288   55.0
# Kaapvaal              3.097600e-02  1.393920e-01  0.216832   1.246784  409.0
# Kalahari              3.097600e-01  3.097600e-01  0.309760   0.309760    1.0
# Pohorje               0.000000e+00  0.000000e+00  0.000000   0.000000   10.0
# Siberia               6.897116e-02  7.279360e-02  0.077622   1.130624  643.0
0.000000e+00  0.000000e+00  0.000000e+00   0.000000
# Gawler                5.714400e-03  5.714400e-03  5.714400e-03   0.007143
# Guyana                0.000000e+00  0.000000e+00  1.214310e+00   6.935853
# Kaapvaal              0.000000e+00  0.000000e+00  8.143020e-01   3.385782
# Kalahari              1.857180e+00  1.857180e+00  1.857180e+00   1.857180
# Pohorje               7.143000e-07  7.143000e-07  3.571504e-01   5.714400
# Siberia               0.000000e+00  7.857300e-03  1.260025e-02   0.031429
# Slave                 0.000000e+00  0.000000e+00  1.821465e+00   5.001886
# Superior              0.000000e+00  8.928750e-03  1.071450e-01   2.378619
# Tarim                 7.143000e-07  7.143000e-07  7.143000e-07   1.428600
# West Africa           0.000000e+00  0.000000e+00  0.000000e+00   0.022840
# Wyoming               0.000000e+00  1.428600e-02  1.428600e-02   2.353619
# Zimbabwe              7.143000e-07  7.143000e-07  7.143000e-07   0.101788
#
#                                     Sr                                        \
#                             max  count     mean      std  min  25%  50%  75%
# craton
# Alluvial              14.493147    0.0      NaN      NaN  NaN  NaN  NaN  NaN
# Amazonia              34.814982  190.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Buffalo Head Terrane  12.071670    6.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Congo                 13.928850    2.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# East European          0.000000   10.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Gawler                 5.278677   17.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Guyana                10.785930   35.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Kaapvaal              20.071830  361.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Kalahari               1.857180    0.0      NaN      NaN  NaN  NaN  NaN  NaN
# Pohorje               15.000300   10.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Siberia               71.430000  626.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Slave                 67.429920  270.0  0.06796  0.31414  0.0  0.0  0.0  0.0
# Superior              11.885952   86.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Tarim                  2.857200   12.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# West Africa            8.407311   98.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Wyoming               11.685948   34.0  0.00000  0.00000  0.0  0.0  0.0  0.0
# Zimbabwe              10.600212   28.0  0.00000  0.00000  0.0  0.0  0.0  0.0
#
#                                    Ba                                          \
#                            max  count      mean       std  min  25%  50%  75%
# craton
# Alluvial                   NaN    0.0       NaN       NaN  NaN  NaN  NaN  NaN
# Amazonia              0.000000  190.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Buffalo Head Terrane  0.000000    6.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Congo                 0.000000    2.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# East European         0.000000   10.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Gawler                0.000000   17.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Guyana                0.000000   35.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Kaapvaal              0.000000  361.0  0.014389  0.202182  0.0  0.0  0.0  0.0
# Kalahari                   NaN    0.0       NaN       NaN  NaN  NaN  NaN  NaN
# Pohorje               0.000000   10.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Siberia               0.000000  633.0  0.036928  0.383683  0.0  0.0  0.0  0.0
# Slave                 1.944857  270.0  2.020076  5.066409  0.0  0.0  0.0  0.0
# Superior              0.000000   86.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Tarim                 0.000000   12.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# West Africa           0.000000   98.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Wyoming               0.000000   34.0  0.000000  0.000000  0.0  0.0  0.0  0.0
# Zimbabwe              0.000000   28.0  0.000000  0.000000  0.0  0.0  0.0  0.0
#
#                                    Na                              \
#                            max  count          mean           std
# craton
# Alluvial                   NaN   38.0  1.011717e-01  3.984021e-01
# Amazonia               0.00000  205.0  1.215133e-01  3.198761e-01
# Buffalo Head Terrane   0.00000    6.0  1.135602e+00  1.551928e+00
# Congo                  0.00000   17.0  1.263412e+00  1.357484e+00
# East European          0.00000   10.0  0.000000e+00  0.000000e+00
# Gawler                 0.00000   17.0  1.457615e-02  7.960060e-03
# Guyana                 0.00000   55.0  7.481050e-01  1.387805e+00
# Kaapvaal               3.40328  409.0  3.747946e-01  1.334917e+00
# Kalahari                   NaN    0.0           NaN           NaN
# Pohorje                0.00000   10.0  7.419000e-07  1.116064e-22
# Siberia                7.88128  643.0  4.915647e-01  1.456176e+00
# Slave                 42.80968  302.0  1.310588e+00  5.631593e+00
# Superior               0.00000   86.0  8.209210e-02  3.276752e-01
# Tarim                  0.00000   12.0  7.419000e-07  0.000000e+00
# West Africa            0.00000   98.0  5.452708e-01  3.637045e+00
# Wyoming                0.00000   34.0  9.491956e-02  4.392740e-01
# Zimbabwe               0.00000   28.0  1.123456e-01  5.944730e-01
#
#                                                                               \
#                                min           25%           50%           75%
# craton
# Alluvial              1.187040e-02  1.187040e-02  1.187040e-02  1.483800e-02
# Amazonia              0.000000e+00  1.187040e-02  1.187040e-02  3.709500e-02
# Buffalo Head Terrane  1.780560e-02  8.346375e-02  2.485365e-01  2.377790e+00
# Congo                 0.000000e+00  9.644700e-02  9.718890e-01  1.654437e+00
# East European         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Gawler                0.000000e+00  1.187040e-02  1.187040e-02  2.225700e-02
# Guyana                0.000000e+00  0.000000e+00  6.677100e-02  3.820785e-01
# Kaapvaal              0.000000e+00  0.000000e+00  0.000000e+00  8.160900e-02
# Kalahari                       NaN           NaN           NaN           NaN
# Pohorje               7.419000e-07  7.419000e-07  7.419000e-07  7.419000e-07
# Siberia               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Slave                 0.000000e+00  0.000000e+00  1.483800e-02  3.672405e-01
# Superior              0.000000e+00  0.000000e+00  0.000000e+00  3.709500e-02
# Tarim                 7.419000e-07  7.419000e-07  7.419000e-07  7.419000e-07
# West Africa           0.000000e+00  0.000000e+00  0.000000e+00  7.233525e-03
# Wyoming               0.000000e+00  0.000000e+00  0.000000e+00  2.782125e-02
# Zimbabwe              7.419000e-07  7.419000e-07  7.419000e-07  7.419000e-07
#
#                                         P                                \
#                                max  count      mean       std       min
# craton
# Alluvial              2.299890e+00   38.0  0.005329  0.004379  0.003491
# Amazonia              2.381499e+00  190.0  0.003810  0.008832  0.000000
# Buffalo Head Terrane  3.182751e+00    6.0  0.000000  0.000000  0.000000
# Congo                 4.303020e+00    2.0  0.000000  0.000000  0.000000
# East European         0.000000e+00   10.0  0.000000  0.000000  0.000000
# Gawler                2.967600e-02   17.0  0.005342  0.003007  0.003493
# Guyana                4.169478e+00   50.0  0.005673  0.020071  0.000000
# Kaapvaal              1.216716e+01  404.0  0.007715  0.073254  0.000000
# Kalahari                       NaN    0.0       NaN       NaN       NaN
# Pohorje               7.419000e-07   10.0  6.854620  4.606998  0.873200
# Siberia               1.053498e+01  633.0  0.113536  0.421452  0.000000
# Slave                 8.976990e+01  297.0  0.149908  1.126176  0.000000
# Superior              2.136672e+00   86.0  0.001401  0.002794  0.000000
# Tarim                 7.419000e-07   12.0  7.094750  3.019837  2.619600
# West Africa           3.553701e+01   98.0  0.000000  0.000000  0.000000
# Wyoming               2.566974e+00   34.0  0.000000  0.000000  0.000000
# Zimbabwe              3.145656e+00   28.0  0.000000  0.000000  0.000000
#
#                                                                    K  \
#                            25%       50%       75%        max  count
# Amazonia              0.0  0.0  0.00000  0.000000e+00  0.000000e+00  205.0
# Buffalo Head Terrane  0.0  0.0  0.00000  0.000000e+00  0.000000e+00    6.0
# Congo                 0.0  0.0  0.00000  0.000000e+00  0.000000e+00   17.0
# East European         0.0  0.0  0.00000  0.000000e+00  0.000000e+00   10.0
# Gawler                0.0  0.0  0.00000  0.000000e+00  0.000000e+00   17.0
# Guyana                0.0  0.0  0.00000  0.000000e+00  0.000000e+00   47.0
# Kaapvaal              0.0  0.0  0.00000  0.000000e+00  0.000000e+00  404.0
# Kalahari              NaN  NaN      NaN           NaN           NaN    0.0
# Pohorje               0.0  0.0  0.00000  0.000000e+00  0.000000e+00   10.0
# Siberia               0.0  0.0  0.01247  1.312671e-02  1.808950e-02  626.0
# Slave                 0.0  0.0  0.00000  0.000000e+00  0.000000e+00  300.0
# Superior              0.0  0.0  0.00000  0.000000e+00  0.000000e+00   86.0
# Tarim                 0.0  0.0  0.00000  0.000000e+00  0.000000e+00   12.0
# West Africa           0.0  0.0  0.00000  0.000000e+00  0.000000e+00   98.0
# Wyoming               0.0  0.0  0.00000  0.000000e+00  0.000000e+00   35.0
# Zimbabwe              0.0  0.0  0.00000  7.865000e-07  7.865000e-07   28.0
#
#                                                                        \
#                           mean        std           min           25%
# craton
# Alluvial              0.091856   0.112534  6.286400e-03  7.858000e-03
# Amazonia              0.506517   5.176372  0.000000e+00  1.571600e-02
# Buffalo Head Terrane  0.000000   0.000000  0.000000e+00  0.000000e+00
# Congo                 0.009245   0.012184  0.000000e+00  7.858000e-07
# East European         0.094296   0.115963  0.000000e+00  0.000000e+00
# Gawler                6.555421  23.828291  1.571600e-02  8.800960e-01
# Guyana                0.183576   0.271876  0.000000e+00  0.000000e+00
# Kaapvaal              0.053298   0.366789  0.000000e+00  0.000000e+00
# Kalahari                   NaN        NaN           NaN           NaN
# Pohorje               0.000000   0.000000  0.000000e+00  0.000000e+00
# Siberia               0.244781   0.197365  0.000000e+00  2.766016e-01
# Slave                 0.063629   0.221853  0.000000e+00  0.000000e+00
# Superior              0.129675   0.121653  0.000000e+00  0.000000e+00
# Tarim                 0.000000   0.000000  0.000000e+00  0.000000e+00
# West Africa           0.089910   0.143129  0.000000e+00  0.000000e+00
# Wyoming               0.176468   0.138726  0.000000e+00  0.000000e+00
# Zimbabwe              0.067635   0.140085  7.858000e-07  7.858000e-07
#
#                                                              S            \
#                                50%       75%        max  count      mean
# craton
# Alluvial              1.571600e-02  0.145373   0.314320    0.0       NaN
# Amazonia              7.858000e-02  0.102154  74.195236  190.0  0.000000
# Buffalo Head Terrane  0.000000e+00  0.000000   0.000000    6.0  0.000000
# Congo                 7.858000e-07  0.015716   0.039290    2.0  0.000000
# East European         3.929000e-02  0.157160   0.314320   10.0  0.000000
# Gawler                9.351020e-01  1.013682  99.010800   17.0  0.000000
# Guyana                0.000000e+00  0.341823   0.887954   35.0  0.000000
# Kaapvaal              0.000000e+00  0.015716   6.844318  361.0  0.000000
# Kalahari                       NaN       NaN        NaN    0.0       NaN
# Pohorje               0.000000e+00  0.000000   0.000000   10.0  0.000000
# Siberia               2.894756e-01  0.296049   4.164740  626.0  0.073348
# Slave                 0.000000e+00  0.000000   1.681612  270.0  0.002074
# Superior              9.822500e-02  0.259314   0.314320   86.0  0.000000
# Tarim                 0.000000e+00  0.000000   0.000000   12.0  0.000000
# West Africa           0.000000e+00  0.291728   0.337894   98.0  0.000000
# Wyoming               2.750300e-01  0.302533   0.322178   34.0  0.000000
# Zimbabwe              7.858000e-07  0.041254   0.518628   28.0  0.000000
#
#                                                              Zn            \
#                            std  min  25%  50%  75%   max  count      mean
# craton
# Alluvial                   NaN  NaN  NaN  NaN  NaN   NaN    0.0       NaN
# Amazonia              0.000000  0.0  0.0  0.0  0.0  0.00  190.0  0.148589
# Buffalo Head Terrane  0.000000  0.0  0.0  0.0  0.0  0.00    6.0  0.000000
# Congo                 0.000000  0.0  0.0  0.0  0.0  0.00    2.0  0.000000
# East European         0.000000  0.0  0.0  0.0  0.0  0.00   10.0  0.000000
# Gawler                0.000000  0.0  0.0  0.0  0.0  0.00   17.0  0.000000
# Guyana                0.000000  0.0  0.0  0.0  0.0  0.00   35.0  0.000000
# Kaapvaal              0.000000  0.0  0.0  0.0  0.0  0.00  361.0  0.000200
# Kalahari                   NaN  NaN  NaN  NaN  NaN   NaN    0.0       NaN
# Pohorje               0.000000  0.0  0.0  0.0  0.0  0.00   10.0  0.000000
# Siberia               0.494784  0.0  0.0  0.0  0.0  7.60  626.0  0.000000
# Slave                 0.034081  0.0  0.0  0.0  0.0  0.56  270.0  0.002289
# Superior              0.000000  0.0  0.0  0.0  0.0  0.00   86.0  0.000000
# Tarim                 0.000000  0.0  0.0  0.0  0.0  0.00   12.0  0.000000
# West Africa           0.000000  0.0  0.0  0.0  0.0  0.00   98.0  0.000000
# Wyoming               0.000000  0.0  0.0  0.0  0.0  0.00   34.0  0.004721
# Zimbabwe              0.000000  0.0  0.0  0.0  0.0  0.00   28.0  0.012898
#
#                                                                       \
#                            std  min  25%           50%           75%
# craton
# Alluvial                   NaN  NaN  NaN           NaN           NaN
# Amazonia              1.037319  0.0  0.0  0.000000e+00  3.210000e-02
# Buffalo Head Terrane  0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Congo                 0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# East European         0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Gawler                0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Guyana                0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Kaapvaal              0.002421  0.0  0.0  0.000000e+00  0.000000e+00
# Kalahari                   NaN  NaN  NaN           NaN           NaN
# Pohorje               0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Siberia               0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Slave                 0.010552  0.0  0.0  0.000000e+00  0.000000e+00
# Superior              0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Tarim                 0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# West Africa           0.000000  0.0  0.0  0.000000e+00  0.000000e+00
# Wyoming               0.013561  0.0  0.0  0.000000e+00  0.000000e+00
# Zimbabwe              0.044405  0.0  0.0  8.025000e-07  8.025000e-07
#
#                                 Cr_trace                            \
#                             max    count         mean          std
# craton
# Alluvial                    NaN      0.0          NaN          NaN
# Amazonia              11.716500     33.0  2362.969697  2453.214874
# Buffalo Head Terrane   0.000000      0.0          NaN          NaN
# Congo                  0.000000      0.0          NaN          NaN
# East European          0.000000      0.0          NaN          NaN
# Gawler                 0.000000      0.0          NaN          NaN
# Guyana                 0.000000     13.0     3.171615    10.611642
# Kaapvaal               0.040125      3.0    19.070667    33.020971
# Kalahari                    NaN      0.0          NaN          NaN
# Pohorje                0.000000      0.0          NaN          NaN
# Siberia                0.000000    552.0   187.170640   245.584070
# Slave                  0.072225     23.0   716.519565  1422.287837
# Superior               0.000000      0.0          NaN          NaN
# Tarim                  0.000000      0.0          NaN          NaN
# West Africa            0.000000     55.0   254.540182   269.417228
# Wyoming                0.056175      0.0          NaN          NaN
# Zimbabwe               0.232725      0.0          NaN          NaN
#
#                                                                            \
#                              min      25%       50%        75%        max
# craton
# Alluvial                     NaN      NaN       NaN        NaN        NaN
# Amazonia              105.000000  286.000  1867.000  3607.0000  11316.000
# Buffalo Head Terrane         NaN      NaN       NaN        NaN        NaN
# Congo                        NaN      NaN       NaN        NaN        NaN
# East European                NaN      NaN       NaN        NaN        NaN
# Gawler                       NaN      NaN       NaN        NaN        NaN
# ...
# Amazonia               168.500    512.50   5921.0      0.0           NaN
# Buffalo Head Terrane       NaN       NaN      NaN      0.0           NaN
# Congo                 5138.500  16922.00  74276.0     82.0   4266.414635
# East European              NaN       NaN      NaN      0.0           NaN
# Gawler                     NaN       NaN      NaN      0.0           NaN
# Guyana                   0.069      0.09      0.1     14.0      0.182429
# Kaapvaal               408.000   1645.00   5010.0      0.0           NaN
# Kalahari               212.000    502.75   1159.0      0.0           NaN
# Pohorje                    NaN       NaN      NaN      0.0           NaN
# Siberia                 11.990     23.98  68990.0    534.0  51588.589724
# Slave                    0.920    290.00   8000.0     74.0     78.701216
# Superior                   NaN       NaN      NaN      0.0           NaN
# Tarim                      NaN       NaN      NaN      0.0           NaN
# West Africa              4.000     39.90   4583.0      0.0           NaN
# Wyoming                353.000    353.00    353.0      0.0           NaN
# Zimbabwe                   NaN       NaN      NaN      0.0           NaN
#
#                                                                         \
#                                std       min           25%         50%
# craton
# Alluvial                       NaN       NaN           NaN         NaN
# Amazonia                       NaN       NaN           NaN         NaN
# Buffalo Head Terrane           NaN       NaN           NaN         NaN
# Congo                  5302.132203  0.000001      0.000001    223.5000
# East European                  NaN       NaN           NaN         NaN
# Gawler                         NaN       NaN           NaN         NaN
# Guyana                    0.152475  0.097000      0.120000      0.1385
# Kaapvaal                       NaN       NaN           NaN         NaN
# Kalahari                       NaN       NaN           NaN         NaN
# Pohorje                        NaN       NaN           NaN         NaN
# Siberia               13164.033038  0.000000  51017.258258  52891.3785
# Slave                   586.061793  0.000000      1.600000      5.2000
# Superior                       NaN       NaN           NaN         NaN
# Tarim                          NaN       NaN           NaN         NaN
# West Africa                    NaN       NaN           NaN         NaN
# Wyoming                        NaN       NaN           NaN         NaN
# Zimbabwe                       NaN       NaN           NaN         NaN
#
#                                               Al_trace                        \
#                               75%         max    count       mean        std
# craton
# Alluvial                      NaN         NaN      0.0        NaN        NaN
# Amazonia                      NaN         NaN      0.0        NaN        NaN
# Buffalo Head Terrane          NaN         NaN      0.0        NaN        NaN
# Congo                  8923.50000   20074.000      0.0        NaN        NaN
# East European                 NaN         NaN      0.0        NaN        NaN
# Gawler                        NaN         NaN      0.0        NaN        NaN
# Guyana                    0.17800       0.700     10.0   1.010100   0.656039
# Kaapvaal                      NaN         NaN      2.0   1.162500   0.894490
# Kalahari                      NaN         NaN      0.0        NaN        NaN
# Pohorje                       NaN         NaN      0.0        NaN        NaN
# Siberia               55369.09668  103901.691    512.0  56.032090  60.524847
# Slave                    12.50000    5050.000     65.0   3.616538  12.792214
# Superior                      NaN         NaN      0.0        NaN        NaN
# Tarim                         NaN         NaN      0.0        NaN        NaN
# West Africa                   NaN         NaN     20.0   1.891800   1.280498
# Wyoming                       NaN         NaN      0.0        NaN        NaN
# Zimbabwe                      NaN         NaN      0.0        NaN        NaN
#
#                                                                        \
#                            min       25%      50%        75%      max
# craton
# Alluvial                   NaN       NaN      NaN        NaN      NaN
# Amazonia                   NaN       NaN      NaN        NaN      NaN
# Buffalo Head Terrane       NaN       NaN      NaN        NaN      NaN
# Congo                      NaN       NaN      NaN        NaN      NaN
# East European              NaN       NaN      NaN        NaN      NaN
# Gawler                     NaN       NaN      NaN        NaN      NaN
# Guyana                0.053000   0.61250   1.0965   1.475000    1.805
# Kaapvaal              0.530000   0.84625   1.1625   1.478750    1.795
# Kalahari                   NaN       NaN      NaN        NaN      NaN
# Pohorje                    NaN       NaN      NaN        NaN      NaN
# Siberia               0.000001  26.46500  47.6370  71.762362  947.447
# Slave                 0.000000   0.50000   1.1000   1.400000   95.500
# Superior                   NaN       NaN      NaN        NaN      NaN
# Tarim                      NaN       NaN      NaN        NaN      NaN
# West Africa           0.000000   1.38250   1.4850   2.122500    5.350
# Wyoming                    NaN       NaN      NaN        NaN      NaN
# Zimbabwe                   NaN       NaN      NaN        NaN      NaN
#
#                      Ca_trace                                               \
#                         count         mean           std     min       25%
# craton
# Alluvial                  0.0          NaN           NaN     NaN       NaN
# Amazonia                 32.0   247.755750    384.744750  27.144  71.23800
# Buffalo Head Terrane      0.0          NaN           NaN     NaN       NaN
# Congo                     0.0          NaN           NaN     NaN       NaN
# East European             0.0          NaN           NaN     NaN       NaN
# Gawler                    0.0          NaN           NaN     NaN       NaN
# Guyana                   22.0     0.423455      0.453358   0.002   0.03975
# Kaapvaal                  2.0     1.093500      0.272236   0.901   0.99725
# Kalahari                  0.0          NaN           NaN     NaN       NaN
# Pohorje                   0.0          NaN           NaN     NaN       NaN
# Siberia                 533.0   130.953453     93.078142   0.000  71.47000
# Slave                    87.0  3020.990805  10455.660599   0.000   0.00000
# Superior                  0.0          NaN           NaN     NaN       NaN
# Tarim                     0.0          NaN           NaN     NaN       NaN
# West Africa              55.0   119.478000    129.738112   0.000   0.53500
# Wyoming                   0.0          NaN           NaN     NaN       NaN
# Zimbabwe                  0.0          NaN           NaN     NaN       NaN
#
#                                                      Mn_trace               \
#                            50%        75%        max    count         mean
# craton
# Alluvial                   NaN        NaN        NaN      0.0          NaN
# Amazonia              136.5000  194.80000   1866.000     36.0  4488.638889
# Buffalo Head Terrane       NaN        NaN        NaN      0.0          NaN
# Congo                      NaN        NaN        NaN     28.0    20.964287
# East European              NaN        NaN        NaN      0.0          NaN
# Gawler                     NaN        NaN        NaN      0.0          NaN
# Guyana                  0.1300    0.91750      1.170     12.0     0.010750
# Kaapvaal                1.0935    1.18975      1.286      2.0     0.011000
# Kalahari                   NaN        NaN        NaN      0.0          NaN
# Pohorje                    NaN        NaN        NaN      0.0          NaN
# Siberia               105.0609  164.38100    615.000    532.0   733.271970
# Slave                   6.4000   21.30000  50134.000     14.0    23.950143
# Superior                   NaN        NaN        NaN      0.0          NaN
# Tarim                      NaN        NaN        NaN      0.0          NaN
# West Africa            98.0000  172.00000    563.000     56.0   473.806429
# Wyoming                    NaN        NaN        NaN      0.0          NaN
# Zimbabwe                   NaN        NaN        NaN      0.0          NaN
#
#                                                                          \
#                               std         min          25%          50%
# craton
# Alluvial                      NaN         NaN          NaN          NaN
# Amazonia              6809.024151  625.000000  1919.000000  2716.500000
# Buffalo Head Terrane          NaN         NaN          NaN          NaN
# Congo                   55.427284    0.000001     0.000001     0.000001
# East European                 NaN         NaN          NaN          NaN
# Gawler                        NaN         NaN          NaN          NaN
# Guyana                   0.006426    0.000000     0.007500     0.010000
# Kaapvaal                 0.009899    0.004000     0.007500     0.011000
# Kalahari                      NaN         NaN          NaN          NaN
# Pohorje                       NaN         NaN          NaN          NaN
# Siberia                328.946208    0.002200   696.960000   727.936000
# Slave                   82.342748    0.022000     1.025000     1.815000
# Superior                      NaN         NaN          NaN          NaN
# Tarim                         NaN         NaN          NaN          NaN
# West Africa            364.195283    0.000000     0.010000   697.500000
# Wyoming                       NaN         NaN          NaN          NaN
# Zimbabwe                      NaN         NaN          NaN          NaN
#
#                                              Mg_trace                 \
#                               75%        max    count           mean
# craton
# Alluvial                      NaN        NaN      0.0            NaN
# Amazonia              3667.250000  39645.000      0.0            NaN
# Buffalo Head Terrane          NaN        NaN      0.0            NaN
# Congo                    0.000001    214.000      0.0            NaN
# East European                 NaN        NaN      0.0            NaN
# Gawler                        NaN        NaN      0.0            NaN
# Guyana                   0.012500      0.021     43.0       1.213112
# Kaapvaal                 0.014500      0.018      2.0       1.271000
# Kalahari                      NaN        NaN      0.0            NaN
# Pohorje                       NaN        NaN      0.0            NaN
# Siberia                758.912000   5147.000    512.0  306538.820689
# Slave                    3.685000    310.000    153.0      36.636144
# Superior                      NaN        NaN      0.0            NaN
# Tarim                         NaN        NaN      0.0            NaN
# West Africa            722.000000   1166.000     12.0       0.833333
# Wyoming                       NaN        NaN      0.0            NaN
# Zimbabwe                      NaN        NaN      0.0            NaN
#
#                                                                         \
#                                std    min            25%           50%
# craton
# Alluvial                       NaN    NaN            NaN           NaN
# Amazonia                       NaN    NaN            NaN           NaN
# Buffalo Head Terrane           NaN    NaN            NaN           NaN
# Congo                          NaN    NaN            NaN           NaN
# East European                  NaN    NaN            NaN           NaN
# Gawler                         NaN    NaN            NaN           NaN
# Guyana                    0.946788  0.560       0.650000       0.88000
# Kaapvaal                  0.018385  1.258       1.264500       1.27100
# Kalahari                       NaN    NaN            NaN           NaN
# Pohorje                        NaN    NaN            NaN           NaN
# Siberia               30835.890412  0.000  307581.953475  310065.99845
# 0  0.0  0.037718  0.0  0.0     136.0      79.0      31.0       0.2    0.300
# 1  0.0  0.094296  0.0  0.0     260.0      56.0     181.0       0.4    0.800
# 2  0.0  0.809374  0.0  0.0    4172.0     429.0    6375.0       1.6    0.144
# 3  0.0  0.037718  0.0  0.0    2944.0     155.0     790.0       0.2    0.300
# 4  0.0  0.055006  0.0  0.0     153.0      53.0      13.0       0.3    0.500
#
#    Zr_trace  Nb_trace  Ba_trace  La_trace  Ce_trace  Nd_trace  Sm_trace  \
# 0      27.4     335.0      4.00     0.600     2.100      0.60     0.192
# 1      56.6     227.0      3.20     0.700     2.400      2.50     0.312
# 2      25.2       4.8      0.56     0.096     0.056      0.32     0.400
# 3     348.7     646.0      2.30     0.500     1.900      0.70     0.300
# 4      68.7     205.0      8.80     0.800     2.900      0.70     0.100
#
#    Eu_trace  Dy_trace  Er_trace  Yb_trace  Ti_trace  Fe_trace  Al_trace  \
# 0    0.0760    0.1472     0.224    0.1000       NaN       NaN       NaN
# 1    0.1112    0.1288     0.392    0.3280       NaN       NaN       NaN
# 2    0.1600    0.3200     0.640    0.3200       NaN       NaN       NaN
# 3    0.0688    0.1864     0.248    0.1544       NaN       NaN       NaN
# 4    0.0000    0.1000     0.256    0.5000       NaN       NaN       NaN
#
#    Ca_trace  Mn_trace  Mg_trace  NAs
# 0    55.640    2706.0       NaN   48
# 1    97.424    3251.0       NaN   48
# 2   156.800    1887.0       NaN   48
# 3    71.488    2397.0       NaN   48
# 4    67.304    2898.0       NaN   48

# %%
df.isna().sum().sum()
# Out:
# 40261

# %%
df=df.drop(df.columns[0], axis=1)

# %%
df=df.drop('NAs', axis=1)

# %%
df.head()
# Out:
#      craton        Si         Ti        Al        Cr    V        Mn      Mg  \
# 0  Amazonia  0.000000  30.353616  0.008470  0.027368  0.0  0.363968   0.270
# 1  Amazonia  0.014000  32.007960  0.047646  0.027368  0.0  0.394944   0.342
# 2  Amazonia  0.070000   0.689310  1.138210  2.155230  0.0  0.201344  29.868
# 3  Amazonia  0.004667  30.101868  0.008470  0.027368  0.0  0.565312   0.072
# 4  Amazonia  0.028000  32.463504  0.068822  0.027368  0.0  0.325248   0.300
#
#          Ca   Sr   Ba        Na    P         K         Fe   Co        Ni    S  \
# 0  0.017143  0.0  0.0  0.023741  0.0  0.026553  37.022328  0.0  0.037718  0.0
# 1  0.028572  0.0  0.0  0.023741  0.0  0.033192  33.281206  0.0  0.094296  0.0
# 2  0.017143  0.0  0.0  0.023741  0.0  0.026553  36.368993  0.0  0.809374  0.0
# 3  0.021429  0.0  0.0  0.023741  0.0  0.026553  35.941214  0.0  0.037718  0.0
# 4  0.017143  0.0  0.0  0.023741  0.0  0.026553  31.290089  0.0  0.055006  0.0
#
#     Zn  Cr_trace  Co_trace  Ni_trace  Sr_trace  Y_trace  Zr_trace  Nb_trace  \
# 0  0.0     136.0      79.0      31.0       0.2    0.300      27.4     335.0
# 1  0.0     260.0      56.0     181.0       0.4    0.800      56.6     227.0
# 2  0.0    4172.0     429.0    6375.0       1.6    0.144      25.2       4.8
# 3  0.0    2944.0     155.0     790.0       0.2    0.300     348.7     646.0
# 4  0.0     153.0      53.0      13.0       0.3    0.500      68.7     205.0
#
#    Ba_trace  La_trace  Ce_trace  Nd_trace  Sm_trace  Eu_trace  Dy_trace  \
# 0      4.00     0.600     2.100      0.60     0.192    0.0760    0.1472
# 1      3.20     0.700     2.400      2.50     0.312    0.1112    0.1288
# 2      0.56     0.096     0.056      0.32     0.400    0.1600    0.3200
# 3      2.30     0.500     1.900      0.70     0.300    0.0688    0.1864
# 4      8.80     0.800     2.900      0.70     0.100    0.0000    0.1000
#
#    Er_trace  Yb_trace  Ti_trace  Fe_trace  Al_trace  Ca_trace  Mn_trace  \
# 0     0.224    0.1000       NaN       NaN       NaN    55.640    2706.0
# 1     0.392    0.3280       NaN       NaN       NaN    97.424    3251.0
# 2     0.640    0.3200       NaN       NaN       NaN   156.800    1887.0
# 3     0.248    0.1544       NaN       NaN       NaN    71.488    2397.0
# 4     0.256    0.5000       NaN       NaN       NaN    67.304    2898.0
#
#    Mg_trace
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.craton.value_counts()
# Out:
# Siberia                 695
# Kaapvaal                410
# Slave                   330
# Amazonia                207
# Congo                   101
# West Africa              98
# Superior                 86
# Guyana                   57
# Alluvial                 38
# Wyoming                  35
# Zimbabwe                 28
# Gawler                   17
# Tarim                    12
# East European            10
# Pohorje                  10
# Buffalo Head Terrane      6
# Kalahari                  4
# Name: craton, dtype: int64

# %%
df.craton.nunique()
# Out:
# 17

# %%
def feature_ratios(a):
    plt.figure(figsize=(16, 10))
    sns.countplot(a, palette="Set2")
    plt.xticks(rotation=45)

# %%
feature_ratios(df.craton)

# %%
df_top5= df[df.craton.isin(['Siberia','Kaapvaal','Slave','Amazonia', 'Congo'])]
df_top5.shape
# Out:
# (1743, 41)

# %%
feature_ratios(df_top5.craton)

# %%
df_top5.craton=df_top5.craton.astype('category')

# %%
df_top5.craton.value_counts()
# Out:
# Siberia     695
# Kaapvaal    410
# Slave       330
# Amazonia    207
# Congo       101
# Name: craton, dtype: int64

# %%
df_top5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1743 entries, 0 to 2143
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   craton    1743 non-null   category
#  1   Si        1582 non-null   float64
#  2   Ti        1582 non-null   float64
#  3   Al        1582 non-null   float64
#  4   Cr        1582 non-null   float64
#  5   V         1464 non-null   float64
#  6   Mn        1575 non-null   float64
#  7   Mg        1581 non-null   float64
#  8   Ca        1582 non-null   float64
#  9   Sr        1449 non-null   float64
#  10  Ba        1456 non-null   float64
#  11  Na        1576 non-null   float64
#  12  P         1526 non-null   float64
#  13  K         1581 non-null   float64
#  14  Fe        1582 non-null   float64
#  15  Co        1449 non-null   float64
#  16  Ni        1552 non-null   float64
#  17  S         1449 non-null   float64
#  18  Zn        1449 non-null   float64
#  19  Cr_trace  611 non-null    float64
#  20  Co_trace  575 non-null    float64
#  21  Ni_trace  686 non-null    float64
#  22  Sr_trace  419 non-null    float64
#  23  Y_trace   293 non-null    float64
#  24  Zr_trace  344 non-null    float64
#  25  Nb_trace  317 non-null    float64
#  26  Ba_trace  361 non-null    float64
#  27  La_trace  406 non-null    float64
#  28  Ce_trace  324 non-null    float64
#  29  Nd_trace  322 non-null    float64
#  30  Sm_trace  319 non-null    float64
#  31  Eu_trace  318 non-null    float64
#  32  Dy_trace  318 non-null    float64
#  33  Er_trace  318 non-null    float64
#  34  Yb_trace  317 non-null    float64
#  35  Ti_trace  913 non-null    float64
#  36  Fe_trace  690 non-null    float64
#  37  Al_trace  579 non-null    float64
#  38  Ca_trace  654 non-null    float64
#  39  Mn_trace  612 non-null    float64
#  40  Mg_trace  667 non-null    float64
# dtypes: category(1), float64(40)
# memory usage: 640.2 KB

# %% [markdown]
# ## Split data into craton and elements

# %%
cratons = df_top5.craton.values
cratons=cratons.astype('str')
cratons
# Out:
# array(['Amazonia', 'Amazonia', 'Amazonia', ..., 'Siberia', 'Siberia',
#        'Siberia'], dtype='<U8')

# %%
craton = df_top5.craton.values
craton=cratons.astype('str')
craton
# Out:
# array(['Amazonia', 'Amazonia', 'Amazonia', ..., 'Siberia', 'Siberia',
#        'Siberia'], dtype='<U8')

# %%
le = LabelEncoder()
cratons = le.fit_transform(cratons)
cratons
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
feature_ratios(craton)

# %%
feature_ratios(cratons)

# %%
features = df_top5.drop(['craton'], axis=1)
features.shape
# Out:
# (1743, 40)

# %%
features.head()
features.columns
# Out:
# Index(['Si', 'Ti', 'Al', 'Cr', 'V', 'Mn', 'Mg', 'Ca', 'Sr', 'Ba', 'Na', 'P',
#        'K', 'Fe', 'Co', 'Ni', 'S', 'Zn', 'Cr_trace', 'Co_trace', 'Ni_trace',
#        'Sr_trace', 'Y_trace', 'Zr_trace', 'Nb_trace', 'Ba_trace', 'La_trace',
#        'Ce_trace', 'Nd_trace', 'Sm_trace', 'Eu_trace', 'Dy_trace', 'Er_trace',
#        'Yb_trace', 'Ti_trace', 'Fe_trace', 'Al_trace', 'Ca_trace', 'Mn_trace',
#        'Mg_trace'],
#       dtype='object')

# %%
def plot_importance(feature_df, model, n_feature):
    '''
    Input:
        feature_df: The feature dataframe / The X_train with column names
        model: The training model
        n_feature: number of feature importance you want to display
    Output:
        A plot with the top n feature importance in decreasing order
    '''
    vals = model.feature_importances_
    df = pd.DataFrame(vals, index=feature_df.columns, columns=['Importance']).sort_values(by='Importance', ascending=False)
    df_n = df.iloc[:n_feature,]
    plt.figure(figsize=(16, 9))
    sns.barplot(df_n.index, df_n.Importance, palette="Set2")
    plt.xticks(rotation=45)

# %%
def get_metrics(mod, X_train, X_test, y_train, y_test):
    """ Returns a data frame of metrics (precision,
        recall, AUC ROC) from training and test sets.
        Assumes model has decision_function() method.
        This will at least work for SVC, LDA, QDA.
    """
    pred_train = mod.predict(X_train)
    pred_test = mod.predict(X_test)
    recall_train = recall_score(y_train, pred_train,average='weighted')
    recall_test = recall_score(y_test, pred_test, average='weighted')
    precision_train = precision_score(y_train, pred_train, average='weighted')
    precision_test = precision_score(y_test, pred_test, average='weighted')
    #rocauc_train = roc_auc_score(y_train, pred_train, average='weighted', multi_class='ovr')
    #rocauc_test = roc_auc_score(y_test, pred_test,average='weighted',multi_class='ovr')
    metrics = {'Set':['Train', 'Test'],
               'Recall':[recall_train, recall_test],
               'Precision':[precision_train, precision_test],
               #'ROC AUC':[rocauc_train, rocauc_test]}
              }
    return pd.DataFrame(metrics)

# %% [markdown]
# ## Split into training set and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(features, cratons, test_size=0.2, 
                                                    stratify = cratons, random_state = 2021)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1394, 40), (349, 40), (1394,), (349,))

# %%
feature_ratios(y_train)

# %% [markdown]
# # XGBoost Base Model

# %%
xgb0 = XGBClassifier(objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
xgb0.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %%
print(get_metrics(xgb0, X_train, X_test, y_train, y_test))
plot_importance(features, xgb0, 35)
# Out:
#      Set    Recall  Precision
# 0  Train  0.989240   0.989298
# 1   Test  0.939828   0.940760

# %% [markdown]
# # Optimize Model

# %% [markdown]
# **Step1** 选择较高的学习速率(learning rate)。一般情况下，学习速率的值为0.1。但是，对于不同的问题，理想的学习速率有时候会在0.05到0.3之间波动。
#
# **Step2** 对于给定的学习速率和决策树数量，进行决策树特定参数调优(max_depth, min_child_weight, gamma, subsample, colsample_bytree)。
#
# **Step3** xgboost的正则化参数的调优。(lambda, alpha)。这些参数可以降低模型的复杂度，从而提高模型的表现。
#
# **Step4** 降低学习速率，确定理想参数。

# %% [markdown]
# # Step1. 初选boosting参数

# %%
xgb1 = XGBClassifier(learning_rate = 0.1, # 把学习速率就设成默认较快的0.1
                     n_estimators=500,
                     max_depth=5, # 起始值在4-6之间都是不错的选择
                     min_child_weight=1, #在这里选了一个比较小的值，因为这是一个极不平衡的分类问题。因此，某些叶子节点下的值会比较小。
                     #gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
xgb1.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %%
print(get_metrics(xgb1, X_train, X_test, y_train, y_test))
plot_importance(features, xgb1, 35)
# Out:
#      Set    Recall  Precision
# 0  Train  1.000000   1.000000
# 1   Test  0.977077   0.977771

# %% [markdown]
# # Step2. 第二步： max_depth 和 min_weight 参数调优 （从此开始需要进行高负荷的栅格搜索(grid search)， 需云计算）

# %%
params_test1 = {
    'max_depth': [2,3,4,5],
    'min_child_weight':[ 0.5, 1, 2, 3]}

# %%
gsearch1 = GridSearchCV(estimator=xgb1,
                        param_grid=params_test1,
                        scoring='accuracy', 
                        cv=5)

# %%
gsearch1.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eval_metric='merror',
#                                      gamma=0, learning_rate=0.1,
#                                      max_delta_step=0, max_depth=5,
#                                      min_child_weight=1, missing=None,
#                                      n_estimators=500, n_jobs=1, nthread=None,
#                                      num_class=5, objective='multi:softprob',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=2021, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [2, 3, 4, 5],
#                          'min_child_weight': [0.5, 1, 2, 3]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print('best_params:{0}'.format(gsearch1.best_params_))
print('best_score:{0}'.format(gsearch1.best_score_))
print('best_estimator:{0}'.format(gsearch1.best_estimator_))
bgm_best1 = gsearch1.best_estimator_
# Out:
# best_params:{'max_depth': 4, 'min_child_weight': 2}
# best_score:0.9698692658776205
# best_estimator:XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Step3: gamma参数调优

# %%
params_test3 = {'gamma':[0, 0.01, 0.02, 0.05]}
xgb2 = XGBClassifier(learning_rate = 0.1, 
                     n_estimators=500,
                     max_depth=4, 
                     min_child_weight=2,
                     #gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
gsearch3 = GridSearchCV(estimator=xgb2 ,
                        param_grid=params_test3,
                        scoring='accuracy', 
                        cv=5)
gsearch3.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eval_metric='merror',
#                                      gamma=0, learning_rate=0.1,
#                                      max_delta_step=0, max_depth=4,
#                                      min_child_weight=2, missing=None,
#                                      n_estimators=500, n_jobs=1, nthread=None,
#                                      num_class=5, objective='multi:softmax',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=2021, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'gamma': [0, 0.01, 0.02, 0.05]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print('best_params:{0}'.format(gsearch3.best_params_))
print('best_score:{0}'.format(gsearch3.best_score_))
print('best_estimator:{0}'.format(gsearch3.best_estimator_))
bgm_best3 = gsearch3.best_estimator_
# Out:
# best_params:{'gamma': 0}
# best_score:0.9698692658776205
# best_estimator:XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Step4: subsample 和 colsample_bytree

# %%
params_test4 = {
    'subsample':[i/10.0 for i in range(3,6)],
    'colsample_bytree':[i/10.0 for i in range(7,11)]
}
xgb3 = XGBClassifier(learning_rate = 0.1, 
                     n_estimators=500,
                     max_depth=4, 
                     min_child_weight=2,
                     gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
gsearch4 = GridSearchCV(estimator=xgb3 ,
                        param_grid=params_test4,
                        scoring='accuracy', 
                        cv=5)
gsearch4.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eval_metric='merror',
#                                      gamma=0, learning_rate=0.1,
#                                      max_delta_step=0, max_depth=4,
#                                      min_child_weight=2, missing=None,
#                                      n_estimators=500, n_jobs=1, nthread=None,
#                                      num_class=5, objective='multi:softmax',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=2021, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
#                          'subsample': [0.3, 0.4, 0.5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print('best_params:{0}'.format(gsearch4.best_params_))
print('best_score:{0}'.format(gsearch4.best_score_))
print('best_estimator:{0}'.format(gsearch4.best_estimator_))
bgm_best4 = gsearch4.best_estimator_
# Out:
# best_params:{'colsample_bytree': 0.9, 'subsample': 0.5}
# best_score:0.9641319202702354
# best_estimator:XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.9, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=0.5, verbosity=1)

# %% [markdown]
# # Step5: 正则化参数 l1, l2

# %%
params_test5 = {
    'reg_alpha':[0, 0.001, 0.005, 0.01],
    'reg_lambda':[0, 0.001, 0.005, 0.01]
}
xgb5 = XGBClassifier(learning_rate = 0.1, 
                     n_estimators=500,
                     max_depth=4, 
                     min_child_weight=2,
                     gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
gsearch5 = GridSearchCV(estimator=xgb5 ,
                        param_grid=params_test5,
                        scoring='accuracy', 
                        cv=5)
gsearch5.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eval_metric='merror',
#                                      gamma=0, learning_rate=0.1,
#                                      max_delta_step=0, max_depth=4,
#                                      min_child_weight=2, missing=None,
#                                      n_estimators=500, n_jobs=1, nthread=None,
#                                      num_class=5, objective='multi:softmax',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=2021, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'reg_alpha': [0, 0.001, 0.005, 0.01],
#                          'reg_lambda': [0, 0.001, 0.005, 0.01]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print('best_params:{0}'.format(gsearch5.best_params_))
print('best_score:{0}'.format(gsearch5.best_score_))
print('best_estimator:{0}'.format(gsearch5.best_estimator_))
bgm_best5 = gsearch5.best_estimator_
# Out:
# best_params:{'reg_alpha': 0, 'reg_lambda': 0}
# best_score:0.9684329955390526
# best_estimator:XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=0, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %% [markdown]
# # Step6: Reduce learning_rate

# %%
params_test6={
    'n_estimators': range(300, 700, 100)
}
xgb6 = XGBClassifier(learning_rate = 0.05, 
                     n_estimators=500,
                     max_depth=4, 
                     min_child_weight=2,
                     gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
gsearch6 = GridSearchCV(estimator=xgb6 ,
                        param_grid=params_test6,
                        scoring='accuracy', 
                        cv=5)
gsearch6.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eval_metric='merror',
#                                      gamma=0, learning_rate=0.05,
#                                      max_delta_step=0, max_depth=4,
#                                      min_child_weight=2, missing=None,
#                                      n_estimators=500, n_jobs=1, nthread=None,
#                                      num_class=5, objective='multi:softmax',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=2021, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_estimators': range(300, 700, 100)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
print('best_params:{0}'.format(gsearch6.best_params_))
print('best_score:{0}'.format(gsearch6.best_score_))
print('best_estimator:{0}'.format(gsearch6.best_estimator_))
bgm_best6 = gsearch6.best_estimator_
# Out:
# best_params:{'n_estimators': 500}
# best_score:0.9677187282432118
# best_estimator:XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %% [markdown]
# **May not use lower learning rate since score decreased**

# %% [markdown]
# # Get the optimzed model

# %%
xgb_best = XGBClassifier(learning_rate = 0.1, 
                     n_estimators=500,
                     max_depth=4, 
                     min_child_weight=2,
                     gamma=0,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
xgb_best.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=4,
#               min_child_weight=2, missing=None, n_estimators=500, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %%
print(get_metrics(xgb_best, X_train, X_test, y_train, y_test))
plot_importance(features, xgb_best, 35)
# Out:
#      Set    Recall  Precision
# 0  Train  1.000000   1.000000
# 1   Test  0.968481   0.968966

# %% [markdown]
# **Check previous cv results**

# %%
xgb_best_p = XGBClassifier(learning_rate = 0.05, 
                     n_estimators=100,
                     max_depth=7, 
                     #min_child_weight=2,
                     gamma=1,
                     #subsample=0.8,
                     #colsample_bytree=0.8,
                     objective='multi:softmax', 
                     num_class = 5, 
                     eval_metric = 'merror', 
                     seed=2021)
xgb_best_p.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=1, learning_rate=0.05, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, num_class=5, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=2021, silent=None, subsample=1, verbosity=1)

# %%
print(get_metrics(xgb_best_p, X_train, X_test, y_train, y_test))
plot_importance(features, xgb_best_p, 35)
# Out:
#      Set    Recall  Precision
# 0  Train  0.992109   0.992113
# 1   Test  0.951289   0.953990

# %% [markdown]
# # Predict Unknown
# ### Assume all samples are from Top 5 Craton
# ## Get and pre-process the unknow dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-41743faf-8538-4ae3-a2c4-fcd1aca1eb66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41743faf-8538-4ae3-a2c4-fcd1aca1eb66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Diamind_XZ_20201216_Unknown.csv to Diamind_XZ_20201216_Unknown.csv

# %%
import io
df_pre = pd.read_csv(io.BytesIO(uploaded['Diamind_XZ_20201216_Unknown.csv']))

# %%
df_pre.head()
# Out:
#    Unnamed: 0    craton        Si         Ti        Al        Cr    V  \
# 0           1  Amazonia  0.000000  30.353616  0.008470  0.027368  0.0
# 1           2  Amazonia  0.014000  32.007960  0.047646  0.027368  0.0
# 2           3  Amazonia  0.070000   0.689310  1.138210  2.155230  0.0
# 3           4  Amazonia  0.004667  30.101868  0.008470  0.027368  0.0
# 4           5  Amazonia  0.028000  32.463504  0.068822  0.027368  0.0
#
#          Mn      Mg        Ca   Sr   Ba        Na    P         K         Fe  \
# 0  0.363968   0.270  0.017143  0.0  0.0  0.023741  0.0  0.026553  37.022328
# 1  0.394944   0.342  0.028572  0.0  0.0  0.023741  0.0  0.033192  33.281206
# 2  0.201344  29.868  0.017143  0.0  0.0  0.023741  0.0  0.026553  36.368993
# 3  0.565312   0.072  0.021429  0.0  0.0  0.023741  0.0  0.026553  35.941214
# 4  0.325248   0.300  0.017143  0.0  0.0  0.023741  0.0  0.026553  31.290089
#
#     Co        Ni    S   Zn  Cr_trace  Co_trace  Ni_trace  Sr_trace  Y_trace  \
# 0  0.0  0.037718  0.0  0.0     136.0      79.0      31.0       0.2    0.300
# 1  0.0  0.094296  0.0  0.0     260.0      56.0     181.0       0.4    0.800
# 2  0.0  0.809374  0.0  0.0    4172.0     429.0    6375.0       1.6    0.144
# 3  0.0  0.037718  0.0  0.0    2944.0     155.0     790.0       0.2    0.300
# 4  0.0  0.055006  0.0  0.0     153.0      53.0      13.0       0.3    0.500
#
#    Zr_trace  Nb_trace  Ba_trace  La_trace  Ce_trace  Nd_trace  Sm_trace  \
# 0      27.4     335.0      4.00     0.600     2.100      0.60     0.192
# 1      56.6     227.0      3.20     0.700     2.400      2.50     0.312
# 2      25.2       4.8      0.56     0.096     0.056      0.32     0.400
# 3     348.7     646.0      2.30     0.500     1.900      0.70     0.300
# 4      68.7     205.0      8.80     0.800     2.900      0.70     0.100
#
#    Eu_trace  Dy_trace  Er_trace  Yb_trace  Ti_trace  Fe_trace  Al_trace  \
# 0    0.0760    0.1472     0.224    0.1000       NaN       NaN       NaN
# 1    0.1112    0.1288     0.392    0.3280       NaN       NaN       NaN
# 2    0.1600    0.3200     0.640    0.3200       NaN       NaN       NaN
# 3    0.0688    0.1864     0.248    0.1544       NaN       NaN       NaN
# 4    0.0000    0.1000     0.256    0.5000       NaN       NaN       NaN
#
#    Ca_trace  Mn_trace  Mg_trace  NAs
# 0    55.640    2706.0       NaN   48
# 1    97.424    3251.0       NaN   48
# 2   156.800    1887.0       NaN   48
# 3    71.488    2397.0       NaN   48
# 4    67.304    2898.0       NaN   48

# %%
uk = df_pre.copy()
uk.shape
# Out:
# (2162, 43)

# %%
uk.columns #Keep NA to see NA's impact
# Out:
# Index(['Unnamed: 0', 'craton', 'Si', 'Ti', 'Al', 'Cr', 'V', 'Mn', 'Mg', 'Ca',
#        'Sr', 'Ba', 'Na', 'P', 'K', 'Fe', 'Co', 'Ni', 'S', 'Zn', 'Cr_trace',
#        'Co_trace', 'Ni_trace', 'Sr_trace', 'Y_trace', 'Zr_trace', 'Nb_trace',
#        'Ba_trace', 'La_trace', 'Ce_trace', 'Nd_trace', 'Sm_trace', 'Eu_trace',
#        'Dy_trace', 'Er_trace', 'Yb_trace', 'Ti_trace', 'Fe_trace', 'Al_trace',
#        'Ca_trace', 'Mn_trace', 'Mg_trace', 'NAs'],
#       dtype='object')

# %%
uk.drop(uk.columns[uk.isna().mean() == 1], axis=1, inplace=True)  # Remove columns that 100% missing 
uk.shape
# Out:
# (2162, 43)

# %%
uk=uk.drop(uk.columns[0], axis=1)

# %%
uk=uk.drop('NAs', axis=1)

# %%
uk.head()
# Out:
#      craton        Si         Ti        Al        Cr    V        Mn      Mg  \
# 0  Amazonia  0.000000  30.353616  0.008470  0.027368  0.0  0.363968   0.270
# 1  Amazonia  0.014000  32.007960  0.047646  0.027368  0.0  0.394944   0.342
# 2  Amazonia  0.070000   0.689310  1.138210  2.155230  0.0  0.201344  29.868
# 3  Amazonia  0.004667  30.101868  0.008470  0.027368  0.0  0.565312   0.072
# 4  Amazonia  0.028000  32.463504  0.068822  0.027368  0.0  0.325248   0.300
#
#          Ca   Sr   Ba        Na    P         K         Fe   Co        Ni    S  \
# 0  0.017143  0.0  0.0  0.023741  0.0  0.026553  37.022328  0.0  0.037718  0.0
# 1  0.028572  0.0  0.0  0.023741  0.0  0.033192  33.281206  0.0  0.094296  0.0
# 2  0.017143  0.0  0.0  0.023741  0.0  0.026553  36.368993  0.0  0.809374  0.0
# 3  0.021429  0.0  0.0  0.023741  0.0  0.026553  35.941214  0.0  0.037718  0.0
# 4  0.017143  0.0  0.0  0.023741  0.0  0.026553  31.290089  0.0  0.055006  0.0
#
#     Zn  Cr_trace  Co_trace  Ni_trace  Sr_trace  Y_trace  Zr_trace  Nb_trace  \
# 0  0.0     136.0      79.0      31.0       0.2    0.300      27.4     335.0
# 1  0.0     260.0      56.0     181.0       0.4    0.800      56.6     227.0
# 2  0.0    4172.0     429.0    6375.0       1.6    0.144      25.2       4.8
# 3  0.0    2944.0     155.0     790.0       0.2    0.300     348.7     646.0
# 4  0.0     153.0      53.0      13.0       0.3    0.500      68.7     205.0
#
#    Ba_trace  La_trace  Ce_trace  Nd_trace  Sm_trace  Eu_trace  Dy_trace  \
# 0      4.00     0.600     2.100      0.60     0.192    0.0760    0.1472
# 1      3.20     0.700     2.400      2.50     0.312    0.1112    0.1288
# 2      0.56     0.096     0.056      0.32     0.400    0.1600    0.3200
# 3      2.30     0.500     1.900      0.70     0.300    0.0688    0.1864
# 4      8.80     0.800     2.900      0.70     0.100    0.0000    0.1000
#
#    Er_trace  Yb_trace  Ti_trace  Fe_trace  Al_trace  Ca_trace  Mn_trace  \
# 0     0.224    0.1000       NaN       NaN       NaN    55.640    2706.0
# 1     0.392    0.3280       NaN       NaN       NaN    97.424    3251.0
# 2     0.640    0.3200       NaN       NaN       NaN   156.800    1887.0
# 3     0.248    0.1544       NaN       NaN       NaN    71.488    2397.0
# 4     0.256    0.5000       NaN       NaN       NaN    67.304    2898.0
#
#    Mg_trace
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
preds=uk.loc[(uk['craton']=='Unknown')].drop(['craton'], axis=1)

# %%
preds.head()
# Out:
#             Si            Ti        Al            Cr    V            Mn  \
# 78         NaN           NaN       NaN           NaN  NaN           NaN
# 334  18.666800  1.078920e+00  5.029300  0.000000e+00  0.0  9.292800e-02
# 501  19.362138  5.994000e-07  0.121762  6.842000e-07  NaN  7.744000e-07
# 502  19.632807  5.994000e-07  0.079410  6.842000e-07  NaN  7.744000e-07
# 503  19.628140  5.994000e-07  9.110974  6.034644e+00  NaN  2.168320e-01
#
#          Mg         Ca   Sr   Ba            Na         P             K  \
# 78      NaN        NaN  NaN  NaN           NaN       NaN           NaN
# 334   3.240  15.571740  0.0  0.0  2.077320e+00  0.760077  4.978740e+00
# 501  30.066   0.171432  NaN  NaN  7.419000e-07       NaN  8.301000e-07
# 502  30.252   0.135717  NaN  NaN  7.419000e-07       NaN  8.301000e-07
# 503  12.798   2.757198  NaN  NaN  7.419000e-07       NaN  8.301000e-07
#
#            Fe   Co        Ni    S   Zn  Cr_trace  Co_trace  Ni_trace  \
# 78        NaN  NaN       NaN  NaN  NaN       NaN       NaN       NaN
# 334  0.000000  0.0  0.000000  0.0  0.0    1111.0       NaN       NaN
# 501  4.791125  NaN  0.227882  0.0  0.0       NaN       NaN       NaN
# 502  5.234459  NaN  0.282888  0.0  0.0       NaN       NaN       NaN
# 503  5.016681  NaN  0.000000  0.0  0.0       NaN       NaN       NaN
#
#      Sr_trace  Y_trace  Zr_trace  Nb_trace  Ba_trace  La_trace  Ce_trace  \
# 78      360.0      2.0      12.0      51.0     520.0      48.0      68.0
# 334    4389.0    165.0     967.0     413.0    6658.0     990.0    2067.0
# 501       NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 502       NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 503       NaN      NaN       NaN       NaN       NaN       NaN       NaN
#
#      Nd_trace  Sm_trace  Eu_trace  Dy_trace  Er_trace  Yb_trace  Ti_trace  \
# 78       21.0       2.0       0.4       0.5      0.19      0.14     390.0
# 334     813.0     116.0      32.0      63.0     49.00     26.00       NaN
# 501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Fe_trace  Al_trace  Ca_trace  Mn_trace  Mg_trace
# 78        NaN       NaN    4000.0       NaN       NaN
# 334       NaN       NaN       NaN       NaN       NaN
# 501       NaN       NaN       NaN       NaN       NaN
# 502       NaN       NaN       NaN       NaN       NaN
# 503       NaN       NaN       NaN       NaN       NaN

# %%
preds.shape
# Out:
# (18, 40)

# %%
preds.isnull().sum().sum() /(preds.shape[0]* preds.shape[1])
# Out:
# 0.5319444444444444

# %% [markdown]
# # Predicting based on oversampling

# %%
uk_preds = xgb_best.predict(preds)
uk_preds
# Out:
# array([4, 0, 4, 4, 2, 4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4])

# %%
feature_ratios(le.inverse_transform(uk_preds))

# %%
le.inverse_transform(uk_preds)
# Out:
# array(['Slave', 'Amazonia', 'Slave', 'Slave', 'Kaapvaal', 'Slave',
#        'Slave', 'Slave', 'Slave', 'Slave', 'Congo', 'Slave', 'Slave',
#        'Slave', 'Slave', 'Slave', 'Slave', 'Slave'], dtype='<U8')

# %%
results=preds.copy()

# %%
results['craton_pred']=le.inverse_transform(uk_preds)

# %%
results.head()
# Out:
#             Si            Ti        Al            Cr    V            Mn  \
# 78         NaN           NaN       NaN           NaN  NaN           NaN
# 334  18.666800  1.078920e+00  5.029300  0.000000e+00  0.0  9.292800e-02
# 501  19.362138  5.994000e-07  0.121762  6.842000e-07  NaN  7.744000e-07
# 502  19.632807  5.994000e-07  0.079410  6.842000e-07  NaN  7.744000e-07
# 503  19.628140  5.994000e-07  9.110974  6.034644e+00  NaN  2.168320e-01
#
#          Mg         Ca   Sr   Ba            Na         P             K  \
# 78      NaN        NaN  NaN  NaN           NaN       NaN           NaN
# 334   3.240  15.571740  0.0  0.0  2.077320e+00  0.760077  4.978740e+00
# 501  30.066   0.171432  NaN  NaN  7.419000e-07       NaN  8.301000e-07
# 502  30.252   0.135717  NaN  NaN  7.419000e-07       NaN  8.301000e-07
# 503  12.798   2.757198  NaN  NaN  7.419000e-07       NaN  8.301000e-07
#
#            Fe   Co        Ni    S   Zn  Cr_trace  Co_trace  Ni_trace  \
# 78        NaN  NaN       NaN  NaN  NaN       NaN       NaN       NaN
# 334  0.000000  0.0  0.000000  0.0  0.0    1111.0       NaN       NaN
# 501  4.791125  NaN  0.227882  0.0  0.0       NaN       NaN       NaN
# 502  5.234459  NaN  0.282888  0.0  0.0       NaN       NaN       NaN
# 503  5.016681  NaN  0.000000  0.0  0.0       NaN       NaN       NaN
#
#      Sr_trace  Y_trace  Zr_trace  Nb_trace  Ba_trace  La_trace  Ce_trace  \
# 78      360.0      2.0      12.0      51.0     520.0      48.0      68.0
# 334    4389.0    165.0     967.0     413.0    6658.0     990.0    2067.0
# 501       NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 502       NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 503       NaN      NaN       NaN       NaN       NaN       NaN       NaN
#
#      Nd_trace  Sm_trace  Eu_trace  Dy_trace  Er_trace  Yb_trace  Ti_trace  \
# 78       21.0       2.0       0.4       0.5      0.19      0.14     390.0
# 334     813.0     116.0      32.0      63.0     49.00     26.00       NaN
# 501       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 502       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 503       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      Fe_trace  Al_trace  Ca_trace  Mn_trace  Mg_trace craton_pred
# 78        NaN       NaN    4000.0       NaN       NaN       Slave
# 334       NaN       NaN       NaN       NaN       NaN    Amazonia
# 501       NaN       NaN       NaN       NaN       NaN       Slave
# 502       NaN       NaN       NaN       NaN       NaN       Slave
# 503       NaN       NaN       NaN       NaN       NaN    Kaapvaal

# %%
# move 'craton_pred' to top of the dataframe
craton_pred = results['craton_pred']
results.drop(labels=['craton_pred'], axis=1,inplace = True)
results.insert(0, 'craton_pred', craton_pred)
results
# Out:
#      craton_pred         Si            Ti            Al            Cr    V  \
# 78         Slave        NaN           NaN           NaN           NaN  NaN
# 334     Amazonia  18.666800  1.078920e+00  5.029300e+00  0.000000e+00  0.0
# 501        Slave  19.362138  5.994000e-07  1.217620e-01  6.842000e-07  NaN
# 502        Slave  19.632807  5.994000e-07  7.941000e-02  6.842000e-07  NaN
# 503     Kaapvaal  19.628140  5.994000e-07  9.110974e+00  6.034644e+00  NaN
# 504        Slave   0.000000  8.391600e-02  2.826996e+00  4.445247e+01  NaN
# 505        Slave  26.138187  5.994000e-07  1.688786e+00  1.094720e-01  NaN
# 506        Slave  18.741467  5.994000e-07  5.294000e-07  6.842000e-07  NaN
# 507        Slave   0.000000  1.078920e-01  2.636412e+00  4.537614e+01  NaN
# 508        Slave   0.000000  1.198800e-01  2.535826e+00  4.615613e+01  NaN
# 509        Congo  26.898859  1.798200e-02  4.658720e-01  2.873640e-01  NaN
# 510        Slave  19.194137  0.000000e+00  5.294000e-02  5.473600e-02  NaN
# 1095       Slave  23.058165  4.855140e-01  3.065226e+00  0.000000e+00  0.0
# 1096       Slave  22.232159  7.792200e-01  3.991676e+00  0.000000e+00  0.0
# 1097       Slave  22.610162  7.792200e-01  3.742858e+00  6.842000e-03  0.0
# 1098       Slave  22.297493  8.271720e-01  4.769894e+00  1.368400e-02  0.0
# 2152       Slave   0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.0
# 2153       Slave   0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.0
#
#                 Mn      Mg            Ca   Sr   Ba            Na         P  \
# 78             NaN     NaN           NaN  NaN  NaN           NaN       NaN
# 334   9.292800e-02   3.240  1.557174e+01  0.0  0.0  2.077320e+00  0.760077
# 501   7.744000e-07  30.066  1.714320e-01  NaN  NaN  7.419000e-07       NaN
# 502   7.744000e-07  30.252  1.357170e-01  NaN  NaN  7.419000e-07       NaN
# 503   2.168320e-01  12.798  2.757198e+00  NaN  NaN  7.419000e-07       NaN
# 504   7.744000e-07   7.290  7.143000e-07  NaN  NaN  7.419000e-07       NaN
# 505   7.744000e-07   9.810  1.087165e+01  NaN  NaN  1.446705e+00       NaN
# 506   7.744000e-07  29.190  7.143000e-02  NaN  NaN  7.419000e-07       NaN
# 507   7.744000e-07   7.800  7.143000e-07  NaN  NaN  7.419000e-07       NaN
# 508   0.000000e+00   7.848  0.000000e+00  NaN  NaN  0.000000e+00       NaN
# 509   6.195200e-02  21.180  4.857240e-01  NaN  NaN  4.451400e-02       NaN
# 510   3.872000e-02  29.970  2.142900e-02  NaN  NaN  0.000000e+00       NaN
# 1095  2.555520e-01   7.494  1.333598e+01  0.0  0.0  7.938330e-01  0.000000
# 1096  2.632960e-01   6.858  1.355027e+01  0.0  0.0  8.309280e-01  0.000000
# 1097  2.478080e-01   6.918  1.360741e+01  0.0  0.0  8.902800e-01  0.000000
# 1098  1.471360e-01   7.512  1.425028e+01  0.0  0.0  6.899670e-01  0.000000
# 2152  0.000000e+00   0.000  0.000000e+00  0.0  0.0  0.000000e+00  0.000000
# 2153  0.000000e+00   0.000  0.000000e+00  0.0  0.0  0.000000e+00  0.000000
#
#                  K         Fe   Co            Ni    S   Zn  Cr_trace  \
# 78             NaN        NaN  NaN           NaN  NaN  NaN       NaN
# 334   4.978740e+00   0.000000  0.0  0.000000e+00  0.0  0.0  1111.000
# 501   8.301000e-07   4.791125  NaN  2.278820e-01  0.0  0.0       NaN
# 502   8.301000e-07   5.234459  NaN  2.828880e-01  0.0  0.0       NaN
# 503   8.301000e-07   5.016681  NaN  0.000000e+00  0.0  0.0       NaN
# 504   8.301000e-07  13.113371  NaN  1.885920e-01  0.0  0.0       NaN
# 505   8.301000e-07   5.390015  NaN  7.858000e-07  0.0  0.0       NaN
# 506   8.301000e-07   5.631127  0.0  3.693260e-01  0.0  NaN       NaN
# 507   8.301000e-07  11.472255  0.0  0.000000e+00  0.0  NaN       NaN
# 508   8.301000e-07  11.495588  0.0  0.000000e+00  0.0  NaN       NaN
# 509   1.659580e-02   3.157787  0.0  1.178700e-01  0.0  NaN       NaN
# 510   8.301000e-07   5.755572  0.0  0.000000e+00  0.0  NaN       NaN
# 1095  0.000000e+00   8.283357  0.0  0.000000e+00  0.0  0.0     0.000
# 1096  0.000000e+00   8.368913  0.0  0.000000e+00  0.0  0.0     0.000
# 1097  0.000000e+00   8.314468  0.0  0.000000e+00  0.0  0.0     0.000
# 1098  0.000000e+00   5.677794  0.0  0.000000e+00  0.0  0.0     0.001
# 2152  0.000000e+00   0.000000  0.0  0.000000e+00  0.0  0.0       NaN
# 2153  0.000000e+00   0.000000  0.0  0.000000e+00  0.0  0.0       NaN
#
#       Co_trace  Ni_trace  Sr_trace  Y_trace  Zr_trace  Nb_trace  Ba_trace  \
# 78         NaN       NaN     360.0    2.000     12.00     51.00     520.0
# 334        NaN       NaN    4389.0  165.000    967.00    413.00    6658.0
# 501        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 502        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 503        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 504        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 505        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 506        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 507        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 508        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 509        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 510        NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1095       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1096       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1097       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 1098       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# 2152     0.103      1.42      10.8    0.034      0.96      3.52      60.0
# 2153     0.004      0.49       NaN      NaN       NaN       NaN       NaN
#
#       La_trace  Ce_trace  Nd_trace  Sm_trace  Eu_trace  Dy_trace   Er_trace  \
# 78      48.000    68.000    21.000     2.000     0.400     0.500   0.190000
# 334    990.000  2067.000   813.000   116.000    32.000    63.000  49.000000
# 501        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 502        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 503        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 504        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 505        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 506        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 507        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 508        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 509        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 510        NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1095       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1096       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1097       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1098       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 2152     4.280     5.140     1.320     0.110     0.022     0.024   0.000001
# 2153     0.001     0.001     0.041     0.008       NaN     0.019   0.000001
#
#       Yb_trace  Ti_trace  Fe_trace  Al_trace  Ca_trace  Mn_trace  Mg_trace
# 78        0.14   390.000       NaN       NaN  4000.000       NaN       NaN
# 334      26.00       NaN       NaN       NaN       NaN       NaN       NaN
# 501        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 502        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 503        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 504        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 505        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 506        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 507        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 508        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 509        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 510        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1095       NaN     0.037       NaN     0.312     0.764     0.010     0.643
# 1096       NaN     0.037       NaN     0.334     0.765     0.011     0.641
# 1097       NaN     0.023       NaN     0.256     0.750     0.010     0.698
# 1098       NaN     0.039       NaN     0.395     0.795     0.006     0.694
# 2152       NaN     8.910     101.0     9.300   199.000     3.440   240.000
# 2153       NaN       NaN       NaN       NaN       NaN       NaN       NaN
